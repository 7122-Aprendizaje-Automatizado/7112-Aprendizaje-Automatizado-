# %% [markdown]
# # Variables y tipos de datos

# %%
# Booleanos
es_mayor = False

# %%
# Números
x = 10 # Enteros, Int
y = 20.5 # Decimales, Float
z = 3 + 4j # Complejos.

# Cadenas
nombre = "Juan"
apellido = 'Pérez'

# Listas
frutas = ['manzana', 'banana', 'pera']
numeros = [1,2,3,4,5]

# Tuplas
coordenadas = (10, 20)
x_coor, y_coor = coordenadas

# Diccionarios
persona = {'nombre': 'Juan', 'apellido': 'Pérez', 'edad': 30}

# Conjuntos
colores = {'rojo', 'verde', 'azul'}

# Booleanos
es_mayor = True

# Tipos nativos
valor_nulo = None

# %%
diccionarion = {}
for ind in range(0,100):
  diccionarion[f"var1{ind}"] = ind

# %%
frutasdos = frutas.copy()
print(frutasdos)
frutasdos.append('limon')
print(frutasdos)
print(frutas)
# Out:
# ['manzana', 'banana', 'pera']
# ['manzana', 'banana', 'pera', 'limon']
# ['manzana', 'banana', 'pera']

# %%
lista_0 = [0]
ceros = [lista_0.copy() for i in range(10)] #
ceros[0].append(7)
ceros
# Out:
# [[0, 7], [0], [0], [0], [0], [0], [0], [0], [0], [0]]

# %%
import numpy as np

# %%
type(np.array([3.14]))
#is int
# Out:
# numpy.ndarray

# %% [markdown]
# ----------------------------Usos Comunes.----------------------------

# %%
es_rojo = 'rojo' in colores

# %%
# Números: operaciones aritméticas
suma = x + y
resta = x - y
multiplicacion = x * y
division = x / y

# Cadenas: concatenación y formato.
nombre_completo = nombre + " " + apellido
saludo = "Hola, {} {} ".format(nombre, apellido)
saludo_dos = f"Hola, {nombre} {apellido} {None}"

# Listas: acceso a elementos y modificación
primera_fruta = frutas[0]
frutas.append('kiwi')

# Tuplas: acceso a elementos #Las tuplas no aceptan modificaciones
x_coord = coordenadas[0]

# Diccionarios: acceso a valores por clave
edad = persona['edad']

#Creación o acceso a llave o key.
persona['direccion'] = 'Calle 123'

# Conjuntos: prueba de pertenencia y operaciones
es_rojo = 'rojo' in colores
colores_union = colores.union({'amarillo'})

# Booleanos: control de flujo
if es_mayor:
    print("Es mayor de edad")
else:
    print("No es mayor de edad")

# Tipos nativos: validación de nulos
if valor_nulo is None:
    print("El valor es nulo")
# Out:
# Es mayor de edad
# El valor es nulo

# %% [markdown]
# #Operadores y expresiones.

# %%
es_igual = 5 == 3
es_igual
es_verdad = not[[(5 > 3) and (2 < 4)] or (False)]
es_verdad
# Out:
# False

# %%
# Aritméticos
resultado = 5 + 3

# de asignación
x = 5
x += 3

# de comparación
es_igual = 5 == 3

# lógicos
es_verdad = not[[(5 > 3) and (2 < 4)] or (False)]

# de pertenencia
frutas = ['manzana', 'banana', 'pera']
es_fruta = 'banana' in frutas

# de identidad
x = [1, 2, 3]
y = [1, 2, 3]
son_identicos = x is y

# %%
var = 0
while True:
  var += 1
  if var == 100:
    print(var,'>> var primer condicional')
    continue
  if var == 100 or var ==200:
    print(var,'>> var')
    break
# Out:
# 100 >> var primer condicional
# 200 >> var

# %% [markdown]
# #Estructuras de control de flujo (if, for, while).

# %%
var = 10
if var == 0:
  pass
elif var == 1:
  pass
else:
  pass

# %%
# Sentencia if-else
x = 5
if x > 0:
  print('x es positivo')
else:
  print('x es negativo o cero')

# Sentencia for
frutas = ['manzana', 'banana', 'pera']
for aux_fruta in frutas:
  print(aux_fruta)

# Sentencia while
i = 0
while i < 5:
  print(i)
  i += 1

# Instrucción break
for fruta in frutas:
  if fruta == 'banana':
    break
  print(fruta)

# Instrucción continue
for fruta in frutas:
  if fruta == 'banana':
    continue
  print(fruta)

# Instrucción pass
for fruta in frutas:
  pass  # se puede usar como un placeholder para una implementación futura
# Out:
# x es positivo
# manzana
# banana
# pera
# 0
# 1
# 2
# 3
# 4
# manzana
# manzana
# pera

# %%
edad = 16

if edad < 18:
  pass
elif 50 > edad > 18:
  pass
else:
  print('Hola eres un adulto mayor')

for var in range(1,10):
  print(var)
  if var == 5:
    print('contando', var)
    break
    print('Estoy ejecutando cosas')

pares = [var for var in range(0,10) if var % 2 == 0]
print(pares)
# Out:
# 1
# 2
# 3
# 4
# 5
# contando 5
# [0, 2, 4, 6, 8]

# %% [markdown]
# #Funciones

# %%
def suma(a,b):
  """Esta función suma dos números y devuelve el resultado.
  La suma binaria acepta como entradas numeros flotantes, enteros, strings(Los concatena) """
  return a + b

resultado = suma(3, 5)
print(resultado)

def informacion(*args, **kwargs):
  """Esta función imprime los argumentos variables."""
  print(args)
  print(kwargs)

informacion(1, 2, 3, nombre = 'Juan', edad=30)
# Out:
# 8
# (1, 2, 3)
# {'nombre': 'Juan', 'edad': 30}

# %%
dic_aux = {}
dic_aux['OPT'] = 'DesGrad'

if 'DesGrad' == dic_aux['OPT']:
  "Ejecutamos el desenso del gradiente"
  pass
elif 'DesGradEst' == dic_aux['OPT']:
  "Ejecutamos el desenso del gradiente"
  pass
else:
  print('Oye te falta definir un optimizador')

# %%
funcost0 = lambda x: 0
funcost0(0)
funident = lambda x: x
funident(100)
funcuadratic = lambda x: x**2
funcuadratic(100)
funproyect_x = lambda x,y: x
funproyect_x(50,100)
funproyect_y = lambda x,y: y
funproyect_y(10,20)
funcost0([0,1,2,3,4,5])
# Out:
# 0

# %% [markdown]
# # Modulos y paquetes

# %%
#Es necesario cargar drive
# %run '/content/drive/MyDrive/Cursos-UNAM/Reconocimiento de Patrones y Aprendizaje Automatizado/ModuloPython.ipynb'
# /content/sample_data/mnist_train_small.csv
#Funcion dentro del "Modulo"
hola_modulo()
# Out:
# Función isclose del modulo math con los valores(.3,.1+.1+.1):  True

# %%
hola_modulo_local = lambda : hola_modulo()

# %%
hola_modulo_local()
# Out:
# Función isclose del modulo math con los valores(.3,.1+.1+.1):  True

# %%
def suma_Real(a,b):
  "Esta funcion suma dos valores"
  suma_aux = lambda x,y: sum(x,y)
  return suma_aux(a,b)

# %%
import numpy as np
np.abs(-10)
# Out:
# 10

# %% [markdown]
# # Trabajo con archivos.

# %%
# Crear un archivo de .txt
with open("mi_archivo.txt", "w") as archivo:
  for var in range(10):
    archivo.write("Hola mundo!"+str(var)+'\n')

#Leemos el archivo
with open("mi_archivo.txt", "r") as archivo:
  #contenido = archivo.read()
  #print(contenido)
  for line in archivo:
    print(line)
# Out:
# Hola mundo!0
#
# Hola mundo!1
#
# Hola mundo!2
#
# Hola mundo!3
#
# Hola mundo!4
#
# Hola mundo!5
#
# Hola mundo!6
#
# Hola mundo!7
#
# Hola mundo!8
#
# Hola mundo!9

# %%
file_aux = open('/content/mi_archivo.txt')
for line in file_aux:
  print(line)
file_aux.close()
# Out:
# Hola mundo!0
#
# Hola mundo!1
#
# Hola mundo!2
#
# Hola mundo!3
#
# Hola mundo!4
#
# Hola mundo!5
#
# Hola mundo!6
#
# Hola mundo!7
#
# Hola mundo!8
#
# Hola mundo!9

# %%
#Leer una página como texto
import urllib.request
with urllib.request.urlopen('http://www.textfiles.com/stories/hitch2.txt') as response:
  #with urllib.request.urlopen('https://www.youtube.com/') as response:
  html = response.read()
  print(html)
# Out:
# b' \r\n \r\n \r\n\t\t\t Douglas Adams\r\n \r\n\t   The Restaurant at the End of the Universe\r\n \r\n \r\n=================================================================\r\n \r\nDouglas Adams   The Hitch Hiker\'s Guide to the Galaxy\r\nDouglas Adams   The Restaurant at the End of the Universe\r\nDouglas Adams   Life, the Universe, and Everything\r\nDouglas Adams   So long, and thanks for all the fish\r\n \r\n=================================================================\r\n \r\nTo Jane and James\r\n \r\nwith many thanks\r\n \r\nto Geoffrey Perkins for achieving the Improbable\r\n \r\nto Paddy Kingsland, Lisa Braun and Alick Hale Munro  for  helping\r\nhim\r\n \r\nto John Lloyd for his help with the original Milliways script\r\n \r\nto Simon Brett for starting the whole thing off\r\n \r\nto the Paul Simon album One Trick Pony which I played incessantly\r\nwhile writing this book. Five years is far too long\r\n \r\nAnd with very  special  thanks  to  Jacqui  Graham  for  infinite\
# ...

# %%
#Crear Archivos excel o csv
import pandas as pd
#Pandas es otra libreria que necesita ser installada.
datos = pd.DataFrame({
  "columna1": [1, 3, 2],
  "columna2": ["A", "B", "C"]
})
datos.to_csv("mi_archivo.csv", index=False)

import pandas as pd
datos = pd.read_csv("mi_archivo.csv")
print(datos)
# Out:
#    columna1 columna2
# 0         1        A
# 1         3        B
# 2         2        C

# %%
#Tabla interactiva.
datos
# Out:
#    columna1 columna2
# 0         1        A
# 1         3        B
# 2         2        C

# %% [markdown]
# # Manejo de excepciones.

# %%
try:
  resultado = 1 / 0
except ZeroDivisionError:
  print("No es posible dividir por cero.")
# Out:
# No es posible dividir por cero.

# %%
try:
  numero = int("no es un número")
except ZeroDivisionError:
  print("División por cero.")
except ValueError:
  print("No es un número válido.")
# Out:
# No es un número válido.

# %% [markdown]
# # Orientación a objetos (clases y objetos, Herencias).

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

  def saludar(self):
    "Esta función imprime un string con el nombre de la persona y su edad"
    print(f"Hola, soy {self.nombre} y tengo {self.edad} años.")

  def __str__(self):
     return 'Hola soy un objeto de tipo persona'

persona = Persona("Juan", 30)
persona.saludar()
# Hola, soy Juan y tengo 30 años.
# Out:
# Hola, soy Juan y tengo 30 años.

# %%
print(persona)
# Out:
# Hola soy un objeto de tipo persona

# %%
class Empleado(Persona):

  def __init__(self, nombre, edad, cargo):
    super().__init__(nombre, edad)
    self.cargo = cargo

  def saludar(self):
    super().saludar()
    print(f"trabajo como {self.cargo}.")

  def __str__(self):
     return 'Hola soy un Empleado'

empleado = Empleado("Juan", 30, "Ilustrador")
empleado.saludar()
print(empleado)
# Hola, soy Juan y trabajo como desarrollador.
# Out:
# Hola, soy Juan y tengo 30 años.
# trabajo como Ilustrador.
# Hola soy un Empleado

# %% [markdown]
# # Trabajo con módulos externos.

# %%
# Uso de Numpy
import numpy as np
import matplotlib.pyplot as plt

array = np.array([1, 2, 3, 4])
print(array)
mean = np.mean(array)
print(mean)
# Out:
# [1 2 3 4]
# 2.5

# %%
import matplotlib.pyplot as plt

valores_x = np.linspace(0,2,100)

seno = lambda x: np.sin(2 * np.pi * x)
plt.plot(valores_x, seno(valores_x))
plt.title('Función: Seno')
plt.show()

# %%
expo = lambda x: np.exp(x)
valores_x = np.linspace(-1,5,100)
valores_y = expo(valores_x)

plt.plot(valores_x, valores_y)
plt.title('función: exponencial')
plt.show()

# %%
unifor_arr = np.random.uniform(0,100,10000)
print(np.histogram(unifor_arr))
plt.hist(unifor_arr,bins=10)
plt.title('Histograma')
plt.show()
# Out:
# (array([1028, 1003,  972, 1041, 1018, 1048,  996,  961,  962,  971]), array([1.65814786e-02, 1.00125443e+01, 2.00085070e+01, 3.00044698e+01,
#        4.00004326e+01, 4.99963954e+01, 5.99923582e+01, 6.99883209e+01,
#        7.99842837e+01, 8.99802465e+01, 9.99762093e+01]))

# %%
#Distribución Gaussiana
unifor_arr = np.random.normal(75,15,10000)
plt.hist(unifor_arr,bins=100)
plt.show()

# %% [markdown]
# #Conjuntos de punto flotante

# %% [markdown]
# Los números de punto flotante se representan en el ordenador usando un número finito de bits, lo que significa que hay un número limitado de valores que se pueden representar de manera precisa. Este conjunto de números se conoce como el conjunto de punto flotante y se define en el estándar IEEE 754.

# %%
import math

# %%
b= 1e-3
b
# Out:
# 0.001

# %%
# El valor de math.isclose no siempre es igual a la evaluación con ==
grado = 45
x = 5
if math.isclose(taylor_seno(x, grado), np.math.sin(x)):
    print("Los valores son cercanos.", taylor_seno(x, grado) == math.sin(x))
else:
    print("Los valores no son cercanos.", taylor_seno(x, grado) == math.sin(x))
# Out:
# Los valores son cercanos. False

# %% [markdown]
# Es importante tener en cuenta que los números de punto flotante no son exactos, y debemos ser conscientes de esto al trabajar con ellos en nuestro código.

# %% [markdown]
# #Polinomio de Taylor

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# Este bloque utiliza la serie de Taylor/MacLaurin para $sen(x)$ para calcular el valor de la función para un valor dado de x y un número dado de términos de la serie. Se compara el resultado con el valor real de $sen(x)$ utilizando la función math.isclose(). Si ejecutas el bloque, verás que el resultado es cercano pero no idéntico al valor real de la función debido a la imprecisión de los números de punto flotante.
#
# $sen(x) = Σ_{i=0}^∞ \frac{(-1)^i x^{2i+1}}{(2i+1)!} $
#
# $cos(x) = Σ_{i=0}^∞ \frac{(-1)^i x^{2i}}{(2i)!} $

# %% [markdown]
# #Ejemplo de Polinomio de Taylor

# %%
def taylor_seno(x,grado):
  "Esta función calcula el polinomio de Taylor hasta el grado indicado"
  resultado = 0
  for i_var in range(grado+1):
    x_0 = 0
    termino = ((-1)**i_var * x**(2*i_var+1))/ np.math.factorial(2*i_var + 1)
    resultado += termino
  return resultado

taylor_seno(np.pi, 20)
taylor_seno(0, 20)
# Out:
# 0.0

# %%
#Grafica.

# Valores de las ordenadas y las abscisas.
x_val = np.linspace(0,2*np.pi,100)
y_val = np.sin(x_val)
# Taylor
grado = 18
y_pol = np.array([taylor_seno(yax, grado) for yax in x_val])

# Graficas
plt.figure(figsize=(10,5), dpi=100)
plt.plot(x_val,y_val, label='Numpy')
plt.plot(x_val,y_pol,'--',label='Taylor')
# Con esta función hacemos que aparescan los labels
plt.legend()
# Titulo de la grafica.
plt.title(f'Función $Sen(x)$ y Grado: {grado}')
# Mostramos la grafica(Necesaria para el uso de otro IDE por ejemplo Pycharm)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# Creating a custom function for MAE
def mae_f(y_true, predictions):
    y_true, predictions = np.array(y_true), np.array(predictions)
    return np.mean(np.abs(y_true - predictions))

# %%
# Valores de las ordenadas y las abscisas.
x_val = np.linspace(0,2*np.pi,1000)
y_val = np.sin(x_val)
mae = []
rango = np.array(range(0,30))
for g_ax in rango:
  # Taylor
  y_pol = np.array([taylor_seno(yax, g_ax) for yax in x_val])
  mae.append(mae_f(y_val,y_pol))

plt.plot(rango, mae)
print(min(mae), rango[mae.index(min(mae))])
# Out:
# 1.1841767811325777e-15 18

# %% [markdown]
# TAREA -Usando el codigo de abajo encuentre los valores para cual la grafica se ajusta adeacuandamenete-

# %% [markdown]
# #  Newton-Raphson para raices de forma aproximada e iterativa.

# %% [markdown]
# En este ejemplo, la función f(x) representa la ecuación $sen(x) = 0$ que queremos resolver, y la función df(x) representa su derivada, $cos(x)$. La función newton_raphson implementa el método de Newton-Raphson para encontrar una solución de la ecuación f(x) = 0, empezando desde un punto inicial x0. La función devuelve None si no se pudo encontrar una solución dentro del número máximo de iteraciones especificado.
#
# Si ejecutas el programa, verás que la aproximación de la solución de $sen(x) = 0$ es cercana a pi, pero no idéntica debido a la imprecisión de los números de punto flotante.

# %%
def f(x):
    return math.sin(x) # Usamos la función seno.

def df(x):
    return math.cos(x) # La derivada de seno es coseno.

def newton_raphson(f, df, x0, tol, max_iter):
    x = x0
    for i in range(max_iter):
        fx = f(x)
        if abs(fx) < tol:
            return x
        dfx = df(x)
        if dfx == 0:
            break
        x = x - fx/dfx
    return None

x0 = 4 # x_0 hay que especificar el valor cercano a la raiz que queremos encontrar.
tol = 1e-8
max_iter = 1000

x = newton_raphson(f, df, x0, tol, max_iter)

if x is not None:
    print("Aproximación de la solución de sin(x) = 0:")
    print(x)
    print("Valor real de la solución de sin(x) = 0:")
    print(math.pi)
    if x==math.pi:
      print("Los valores son iguales.")
    else:
      print("Los valores no son iguales.")
else:
    print("No se pudo encontrar una solución.")
# Out:
# Aproximación de la solución de sin(x) = 0:
# 3.141592653589793
# Valor real de la solución de sin(x) = 0:
# 3.141592653589793
# Los valores son cercanos.

# %% [markdown]
# #Ecuación de la recta.
# Recodatorio:
# Si tenemos dos puntos$(x_1,y_1)$ y $(x_2,y_2)$. Podemos generar la recta $L=\{(x,y) \in ℜ^2 / y=(\frac{y_2-y_1}{x_2-x_1})(x-x_1)+y_1 \}$.
#
# Al valor $m = \frac{y_2-y_1}{x_2-x_1}$ se le conoce como pendiente de la recta o *slope* en inglés (es común encontrar en paquetes el término slope, cómo PCA).

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 3]) # x1, x2
y = np.array([2, 4]) # y1, y2

def slope(x1, y1, x2, y2):
    if x1 == x2:
        raise ValueError('Los puntos tienen la misma coordenada x')
    return (y2 - y1) / (x2 - x1)

def line_equation(m, x1, y1):
    return lambda x: m * (x - x1) + y1

x_new = np.linspace(0,5,10)
y_new = line_equation(slope(x[0],y[0],x[1],y[1]),x[0],y[0])(x_new)

plt.plot(x_new, y_new)
plt.plot(x, y,'o')
plt.title(f'Recta que pasa por los puntos:{(x[0],y[0])}, {(x[1],y[1])} \n con pendiente: {slope(x[0],y[0],x[1],y[1])}')
plt.show()

# %% [markdown]
# #Interpolación Lineal.
# La interpolación lineal es un caso particular de la interpolación general de Newton.
# Con el polinomio de interpolación de Newton se logra aproximar un valor de la función f(x) en un valor desconocido de x.
# El caso particular, para que una interpolación sea lineal es en el que se utiliza un polinomio de interpolación de grado 1, que se ajusta a los valores en los puntos $x_{1}$ y $x_{2}$. Se denota de la siguiente manera:
#
# $f(x | x_1;x_2) = f(x_1)+\frac{f(x_2)-f(x_1)}{x_2-x_1}(x-x_1)$
#
# para $x_1 < x < x_2$.

# %%
# Puntos conocidos
x = np.array([1,2,3,4])
y = np.array([6,9,2,5])

# Valor desconocido
x_new = np.linspace(0,5,10)

# Interpolación lineal. Nota es posible cambiar el tipo de interpolacion
y_new = np.interp(x_new, x, y)

plt.plot(x,y, '-o', label='Valores conocidos')
plt.plot(x_new,y_new,'o', label='Valores Interpolados')
plt.title(f"Interpolación Linea")
plt.legend()
plt.show()

# %%
# Puntos conocidos
x = np.linspace(0,2*np.pi,10)
y = np.sin(x)

# Valor desconocido
x_new = np.linspace(0,np.pi*2,201)

# Interpolación lineal. Nota es posible cambiar el tipo de interpolacion
y_new = np.interp(x_new, x, y)

#Grafica
plt.plot(x_new,y_new,'-', label='Valores Interpolados')
plt.plot(x,y, 'o', label='Valores conocidos')
plt.plot(x_new, np.sin(x_new), '--', label='Seno')
plt.title(f"Interpolación Linea")
plt.legend()
plt.show()

# %% [markdown]
# #Polinomio de Newton
#
# Para generar la Interpolación polinómica de Newton debemos calcular:
#
# $f_i(x_0, …,x_i) = \frac{f_{i-1}(x_1, …, x_{i})-f_{i-1}(x_0, …, x_{i-1})}{x_i-x_0}$
#
# Además tenemos que calcular el polinomio cómo:
#
# $p_i(x) = p_{i-1}(x)+f_{i}(x_0, …, x_{i}) Π_{j=0}^{i-1}(x-x_j)$
#
# https://es.wikipedia.org/wiki/Interpolaci%C3%B3n_polin%C3%B3mica_de_Newton

# %%
x = np.array([1,2,3,4])
y = np.array([-20,9,2,20])

def divididas_diferencias(x, y):
    n = len(x)
    coef = y.copy()
    for j in range(1, n):
        for i in range(n-1, j-1, -1):
            coef[i] = (coef[i] - coef[i-1]) / (x[i] - x[i-j])
    return coef

coef = divididas_diferencias(x, y)

def newton_interpolation(x, y, coef, x_new):
    n = len(x)
    p = coef[n-1]
    for i in range(n-2, -1, -1):
        p = coef[i] + (x_new - x[i]) * p
    return p

x_new = np.linspace(0, 5, 201)
y_new = [newton_interpolation(x, y, coef, xi) for xi in x_new]

plt.plot(x_new, y_new, label='Polinomio de Newton')
plt.legend()

plt.plot(x, y, 'o', label='Valores conocidos(Interpolación Lineal)')
plt.legend()
plt.xlabel('x')
plt.ylabel('$p_i(x)$')
plt.title('Polinomio de Newton')
plt.show()

# %%
x = np.linspace(0,2*np.pi,7) # Este es el n= que hay que buscar.
y = np.sin(x) # Para la tarea sustituye por cos(x), o tan(x).


x_new = np.linspace(-1, 2*np.pi+1, 100)
coef = divididas_diferencias(x, y)
y_new = [newton_interpolation(x, y, coef, xi) for xi in x_new]

plt.plot(x_new, y_new, label='Polinomio de Newton')
plt.legend()

plt.plot(x, y, 'o', label='Valores conocidos (Interpolación Lineal)')
plt.legend()

plt.plot(x_new, np.sin(x_new), '--', label='Seno')
plt.title('Interpolación polinómica de Newton')
plt.legend()

plt.show()

# %% [markdown]
# #Polinomio de Lagrange:
#
# Es un método que permite encontrar un polinomio que interpola un conjunto de puntos mediante un sistema de ecuaciones.
# El grado del polinomio resultante depende directamente de la cantidad de puntos dada y se verá en algunos ejemplos que la cantidad de puntos puede generar oscilaciones indeseadas en las curvas generadas dependiendo de la naturaleza de las funciones.
#
# Dado un conjunto de $k + 1$ puntos, es decir, $\{(x_i,y_i)/ i=0,…,k \}$
#
# donde todos los $x_j$ se asumen distintos, el polinomio interpolador en la forma de Lagrange es la combinación lineal:
#
# $L(x) = Σ_{j=0}^{k}y_jl_j(x)$
#
# con:
#
# $l_j(x)=Π_{i=0, i\neq j}^k \frac{x-x_i}{x_j-x_i}$

# %%
import sympy as sym

# INGRESO , Datos de prueba
#xi = np.array([1,2,3,4])
#fi = np.array([6,9,2,5])
xi = np.array([1,2,3,4])
fi = np.array([-20,9,2,20])

# PROCEDIMIENTO
# Polinomio de Lagrange
n = len(xi)
x = sym.Symbol('x')
polinomio = 0
divisorL = np.zeros(n, dtype = float)
for i in range(0,n,1):
    # Termino de Lagrange
    numerador = 1
    denominador = 1
    for j  in range(0,n,1):
        if (j!=i):
            numerador = numerador*(x-xi[j])
            denominador = denominador*(xi[i]-xi[j])
    terminoLi = numerador/denominador

    polinomio = polinomio + terminoLi*fi[i]
    divisorL[i] = denominador

# simplifica el polinomio
polisimple = polinomio.expand()
# para evaluación numérica
px = sym.lambdify(x,polisimple)
# Puntos para la gráfica
muestras = 201
a = np.min(xi)-1
b = np.max(xi)+1
pxi = np.linspace(a,b,muestras)
pfi = px(pxi)

# SALIDA
print('Polinomio de Lagrange: ')
print(polisimple)

# Gráfica
plt.plot(xi,fi,'o-', label = 'Puntos')
plt.plot(pxi,pfi, label = 'Polinomio')
plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Interpolación Lagrange')
plt.show()
# Out:
# Polinomio de Lagrange:
# 61*x**3/6 - 79*x**2 + 1169*x/6 - 146

# %%
#Lagrange para la funcion seno
xi = np.linspace(0,4*np.pi,10)
fi = np.sin(xi)

# PROCEDIMIENTO
# Polinomio de Lagrange
n = len(xi)
x = sym.Symbol('x')
polinomio = 0
divisorL = np.zeros(n, dtype = float)
for i in range(0,n,1):

    # Termino de Lagrange
    numerador = 1
    denominador = 1
    for j  in range(0,n,1):
        if (j!=i):
            numerador = numerador*(x-xi[j])
            denominador = denominador*(xi[i]-xi[j])
    terminoLi = numerador/denominador

    polinomio = polinomio + terminoLi*fi[i]
    divisorL[i] = denominador

# simplifica el polinomio
polisimple = polinomio.expand()
# para evaluación numérica
px = sym.lambdify(x,polisimple)

# Puntos para la gráfica
muestras = 100
a = np.min(xi)-1
b = np.max(xi)+1
pxi = np.linspace(a,b,muestras)
pfi = px(pxi)

# SALIDA
print('Polinomio de Lagrange: ')
print(polisimple)

# Gráfica
plt.plot(pxi,pfi, label = 'Forma de Lagrange')
plt.plot(xi,fi,'o', label = 'Valores Conocidos')
plt.plot(pxi, np.sin(pxi), '--', label='Seno')
plt.legend()
plt.title('Interpolación Lagrange')
plt.show()
# Out:
# Polinomio de Lagrange:
# 1.3104130445179e-6*x**9 - 7.41021118888621e-5*x**8 + 0.0016974439073546*x**7 - 0.0200493787835818*x**6 + 0.12861432607388*x**5 - 0.437043768848138*x**4 + 0.778347810619388*x**3 - 1.10392962493393*x**2 + 1.52467341773116*x
